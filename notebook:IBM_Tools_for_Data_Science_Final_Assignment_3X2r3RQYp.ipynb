# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Name: Mun Yin Ting** <br>
# I am currently a 2nd Year Student studying Bachelor of Computer Science specializing Data Science and extending Artificial Intelligence. My desired occupation is to be a professional and successful data scientist.

# %% [markdown]
# *I am interested in Data Science because it is amazing and facinating that Data Scientist can find valuable information from raw data, and even build model to give predictions. This will create a lot of value economically and socially for the society to improve. It is also wonderful how these hidden information in data that might seem meaningless can contribute so much and give a huge impact on decision making as well as development*

# %% [markdown]
# ### The code below will demonstrate multiplication of 9

# %%
for i in range(10):
    print(i,"* 9 = ", i*9)
# Out:
# 0 * 9 =  0
# 1 * 9 =  9
# 2 * 9 =  18
# 3 * 9 =  27
# 4 * 9 =  36
# 5 * 9 =  45
# 6 * 9 =  54
# 7 * 9 =  63
# 8 * 9 =  72
# 9 * 9 =  81

# %% [markdown]
# <hr> Description </hr> <br>
#
# - The "$`$" highlights a code syntax with the symbol at the beginning and the end of the syntax.
# - For instance the `for` in the above cell demonstrates a **for** loop and `range(10)` indicates the for loop to run 10 times from 0 to 9
#
# 1. Below display a table with 4 row 3 columns
# 2. The table can be built with | symbols such as $|column|column|column|$ for columns and $|-|-|-|$ for horizontal lines
# 3. ~~table as shown below~~
#
# |column|column|column|
# |-|-|-|
# |row|row|row|
# |row|row|row|
# |row|row|row|
#
# **This cell contains:
# 1. Bulleted list with $-$ symbol
# 2. Numbered list with normal numbering
# 3. Strikethrough with $~~$ symbol
# 4. Code/Syntax highlighting with $`$ symbol
# 5. Tables with | symbol
# 6. Horizontal rule with `<hr> </hr>` syntax
